# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder,StandardScaler
data = {
    'Age':[25,32,47,29,41,35,52,23,45,38],
    'Gender':['Male','Female','Male','Female','Male','Female','Male','Female','Male','Female'],
    'PlanType':['Basic','Premium','Standard','Basic','Premium','Standard','Basic','Premium','Standard','Basic'],
    'MonthlyUsage':[120,250,300,150,400,280,100,90,350,200],
    'Churn':[0,1,0,0,1,0,1,0,1,0]
}
df = pd.DataFrame(data)
df.loc[2,'MonthlyUsage']=None
df.loc[7,'Age']=None
print("Original Dataset:")
print(df)
# Out:
# Original Dataset:
#     Age  Gender  PlanType  MonthlyUsage  Churn
# 0  25.0    Male     Basic         120.0      0
# 1  32.0  Female   Premium         250.0      1
# 2  47.0    Male  Standard           NaN      0
# 3  29.0  Female     Basic         150.0      0
# 4  41.0    Male   Premium         400.0      1
# 5  35.0  Female  Standard         280.0      0
# 6  52.0    Male     Basic         100.0      1
# 7   NaN  Female   Premium          90.0      0
# 8  45.0    Male  Standard         350.0      1
# 9  38.0  Female     Basic         200.0      0

# %%
df['Age']=df['Age'].fillna(df['Age'].mean())
df['MonthlyUsage'] = df['MonthlyUsage'].fillna(df['MonthlyUsage'].mean())
print("\n After Filling Missing Values:")
print(df)
# Out:
#  After Filling Missing Values:
#          Age  Gender  PlanType  MonthlyUsage  Churn
# 0  25.000000    Male     Basic    120.000000      0
# 1  32.000000  Female   Premium    250.000000      1
# 2  47.000000    Male  Standard    215.555556      0
# 3  29.000000  Female     Basic    150.000000      0
# 4  41.000000    Male   Premium    400.000000      1
# 5  35.000000  Female  Standard    280.000000      0
# 6  52.000000    Male     Basic    100.000000      1
# 7  38.222222  Female   Premium     90.000000      0
# 8  45.000000    Male  Standard    350.000000      1
# 9  38.000000  Female     Basic    200.000000      0

# %%
le= LabelEncoder()
df['Gender'] =le.fit_transform(df['Gender'])
df['PlanType'] = le.fit_transform(df['PlanType'])
print("\n After Encoding Categorical Columns:")
print(df)
# Out:
#  After Encoding Categorical Columns:
#          Age  Gender  PlanType  MonthlyUsage  Churn
# 0  25.000000       1         0    120.000000      0
# 1  32.000000       0         1    250.000000      1
# 2  47.000000       1         2    215.555556      0
# 3  29.000000       0         0    150.000000      0
# 4  41.000000       1         1    400.000000      1
# 5  35.000000       0         2    280.000000      0
# 6  52.000000       1         0    100.000000      1
# 7  38.222222       0         1     90.000000      0
# 8  45.000000       1         2    350.000000      1
# 9  38.000000       0         0    200.000000      0

# %%
x= df.drop('Churn',axis=1)
y=df['Churn']
print("\n Features(X):")
print(x.head())
print("\n target(Y):")
print(y.head())
x_train,x_test,y_train,y_test = train_test_split(
    x,y,test_size=0.2,random_state=42)
print("\n Training Set Size:",x_train.shape)
print("Test Set Size:",x_test.shape)
#scale the features
scale
# Out:
#  Features(X):
#     Age  Gender  PlanType  MonthlyUsage
# 0  25.0       1         0    120.000000
# 1  32.0       0         1    250.000000
# 2  47.0       1         2    215.555556
# 3  29.0       0         0    150.000000
# 4  41.0       1         1    400.000000
