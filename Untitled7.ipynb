# %%
CREATE TABLE employees (
    emp_id INT PRIMARY KEY,
    emp_name VARCHAR(50),
    department VARCHAR(30),
    city VARCHAR(30),
    salary INT,
    manager_id INT
);
INSERT INTO employees VALUES
(101, 'Amit',   'IT',        'Delhi',    70000, NULL),
(102, 'Riya',   'HR',        'Mumbai',   50000, 101),
(103, 'Karan',  'IT',        'Delhi',    80000, 101),
(104, 'Neha',   'Finance',   'Pune',     60000, 102),
(105, 'Arjun',  'HR',        'Mumbai',   55000, 102),
(106, 'Pooja',  'IT',        'Bangalore',75000, 101),
(107, 'Rohit',  'Sales',     'Delhi',    45000, 104),
(108, 'Sneha',  'Marketing', 'Chennai',  65000, NULL);
# Out:
#   Cell In[3], line 1
#     CREATE TABLE employees (
#            ^
# SyntaxError: invalid syntax
