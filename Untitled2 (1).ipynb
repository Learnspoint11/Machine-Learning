# %%
import pandas as pd

# %%
cff=pd.read_csv("car_price_prediction_.csv")
print(cff)
# Out:
#     Row Labels  Count of Transmission
# 0    Automatic                   1192
# 1       Manual                   1308
# 2  Grand Total                   2500

# %%
cff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Row Labels             3 non-null      object
#  1   Count of Transmission  3 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 108.0+ bytes
