# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
x=[[1],[2],[3],[4]]
y=[2,4,6,8]

model.fit(x,y)
prediction = model.predict([[20]])
print("Prediction for input 5 is:",prediction)
# Out:
# Prediction for input 5 is: [40.]

# %%
user_value =float(input("Enter a number to predict:"))
prediction = model.predict ([[user_value]])
print("Prediction is:",prediction[0])
# Out:
# Enter a number to predict: 10
# Prediction is: 20.0

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,color='blue',label='Data Points')
plt.plot(x,model.predict(x),color='orange',label='Regression Line')
plt.legend(loc='center left',bbox_to_anchor=(1,0.5))
plt.title("Linear Regression Line")
plt.xlabel("X")
plt.ylabel("Y")
plt.tight_layout()
plt.show()

# %%
import numpy as np
weights =np.array([1,2,3,4,5]).reshape(-1,1)
weights
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
weights =np.array([1,2,3,4,5])
weights
# Out:
# array([1, 2, 3, 4, 5])

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
weights =np.array([1,2,3,4,5]).reshape(-1,1)
prices= np.array([30,60,90,120,150])
model =LinearRegression()
model.fit(weights,prices)
user_weight = float(input("Enter the weight of banana(in kg):"))
predicted_price =model.predict([[user_weight]])
print(f"Predicted price for {user_weight} kg bananas =rs{predicted_price[0]:.2f}")
weights
# Out:
# Enter the weight of banana(in kg): 10
# Predicted price for 10.0 kg bananas =rs300.00
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5]])

# %%
import numpy as np 
from sklearn.linear_model import LinearRegression

hours = np.array([0.5,1,2,3,4,5,6,7,8]).reshape(-1,1)
scores = np.array([35,40,45,55,60,68,75,82,88])
model = LinearRegression()
model.fit(hours,scores)
test_hours= 4.5
predicted_score = model.predict([[test_hours]])
print("=== Exam Score prediction ===")
print(f"Predicted Score for {test_hours} hours of study = {predicted_score[0]:.1f}")
# Out:
# === Exam Score prediction ===
# Predicted Score for 4.5 hours of study = 64.0

# %%
import sys 
import numpy as np
import pandas as pd
import matplotlib
import sklearn
print("=== Library Versions ===")
print(f"Python   : {sys.version.split()[0]}")
print(f"Numpy    :{np.__version__}")
print(f"Pandas   :{pd.__version__}")
print(f"Matplotlib : {matplotlib.__version__}")
print(f"scikit-learn :{sklearn.__version__}")
from sklearn.linear_model import LinearRegression
test_model = LinearRegression()
print("Libraries imported Successfully")
# Out:
# === Library Versions ===
# Python   : 3.13.2
# Numpy    :2.2.5
# Pandas   :2.3.2
# Matplotlib : 3.8.4
# scikit-learn :1.7.0
# Libraries imported Successfully

# %% [markdown]
# # Pandas

# %%
import pandas as pd
data = pd.read_csv("student_scores.csv")
data.head(10)
# Out:
#      name  hours  score gender grades class
# 0   Aarav      8     76      M      A    9A
# 1    Riya      5     62      F      B    9B
# 2   Kabir     10     88      M      A   10A
# 3    Sana      4     55      F      C    9A
# 4  Vivaan      7     72      M      B   10B
# 5  Ishita      6     64      F      B    9C
# 6   Rohan      3     48      M      D    9B
# 7   Meera      9     90      F      A   11A
# 8  Aditya      2     38      M      F    9C
# 9   Kavya     11     93      F      A   12A

# %%
print('Columns: ' , data.columns.tolist())
print('\nInfo: ')
data.info()
print('\n Describe: ')
data.describe()
# Out:
# Columns:  ['name', 'hours', 'score', 'gender', 'grades', 'class']
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92 entries, 0 to 91
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    92 non-null     object
#  1   hours   92 non-null     int64
#  2   score   92 non-null     int64
#  3   gender  92 non-null     object
#  4   grades  92 non-null     object
#  5   class   92 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.9+ KB
#
#  Describe:
#            hours      score
# count  92.000000  92.000000
# mean    6.510870  68.836957
# std     2.265336  15.692286
# min     2.000000  35.000000
# 25%     5.000000  57.000000
# 50%     7.000000  70.000000
# 75%     8.000000  82.000000
# max    11.000000  94.000000

# %%
print(data.isnull().sum())
data["score"] = data["score"].fillna(data["score"].mean())
data = data.dropna()
# Out:
# name      0
# hours     0
# score     0
# gender    0
# grades    0
# class     0
# dtype: int64

# %% [markdown]
# # LABEL ENCODER

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["gender"] = le.fit_transform(data["gender"])
print(data.head(20))
# Out:
#        name  hours  score  gender grades class
# 0     Aarav      8     76       1      A    9A
# 1      Riya      5     62       0      B    9B
# 2     Kabir     10     88       1      A   10A
# 3      Sana      4     55       0      C    9A
# 4    Vivaan      7     72       1      B   10B
# 5    Ishita      6     64       0      B    9C
# 6     Rohan      3     48       1      D    9B
# 7     Meera      9     90       0      A   11A
# 8    Aditya      2     38       1      F    9C
# 9     Kavya     11     93       0      A   12A
# 10    Naman      5     60       1      B   10A
# 11   Jhanvi      7     70       0      B   11B
# 12   Pranav      4     52       1      C    9A
# 13     Tara      9     85       0      A   12B
# 14     Yash      6     66       1      B   10C
# 15    Anaya      8     78       0      A   11A
# 16    Harsh      3     45       1      D    9A
# 17     Diya     10     89       0      A   12C
# 18  Sarthak      6     63       1      B   10B
# 19    Manya      7     74       0      B   11B

# %%
x =data[["hours"]]
y=data["score"]
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform (x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# # SCALER

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
data = pd.read_csv("student_scores.csv")
x =data[["hours"]]
y=data["score"]
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform (x_train)
x_test = scaler.transform(x_test)
x_train_df = pd.DataFrame(x_train,columns=x.columns)
x_test_df = pd.DataFrame(x_test,columns=x.columns)
print("Scaled Train Data:")
print(x_train_df.head())
print("\n Scaled Test Data:")
print(x_test_df.head())
# Out:
# Scaled Train Data:
#       hours
# 0  0.632152
# 1  0.632152
# 2  0.184122
# 3 -0.263908
# 4 -0.711938
#
#  Scaled Test Data:
#       hours
# 0  0.632152
# 1  1.080182
# 2 -1.607998
# 3 -2.056027
# 4  0.632152

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print('X_train shape:',x_train.shape)
print('X_test shape:',x_test.shape)
print('Y_train shape:',y_train.shape)
print('Y_test shape',y_test.shape)
print("Mean:",x_train.mean(axis=0))
print("Std:",x_train.std(axis=0))
# Out:
# X_train shape: (73, 1)
# X_test shape: (19, 1)
# Y_train shape: (73,)
# Y_test shape (19,)
# Mean: hours    6.589041
# dtype: float64
# Std: hours    2.247441
# dtype: float64

# %%
data = pd.read_csv("practice_data.csv")
data.head(10)
# Out:
#    hours  gender  score
# 0      9  Female   70.0
# 1      3    Male   48.0
# 2      8    Male    NaN
# 3     10  Female   72.0
# 4      7  Female   60.0
# 5      2  Female    NaN
# 6      9    Male   90.0
# 7      7  Female   41.0
# 8      3    Male   78.0
# 9      9    Male   62.0

# %%
print(data.isnull().sum())
data["score"] = data["score"].fillna(data["score"].mean())
data = data.dropna()
# Out:
# hours     0
# gender    0
# score     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data["gender"] = le.fit_transform(data["gender"])
print(data.head(10))
# Out:
#    hours  gender      score
# 0      9       0  70.000000
# 1      3       1  48.000000
# 2      8       1  69.025641
# 3     10       0  72.000000
# 4      7       0  60.000000
# 5      2       0  69.025641
# 6      9       1  90.000000
# 7      7       0  41.000000
# 8      3       1  78.000000
# 9      9       1  62.000000

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
data = pd.read_csv("practice_data.csv")
x =data[["hours"]]
y=data["score"]
from sklearn.model_selection import train_test_split
x_train, x_test,y_train,y_test= train_test_split(x,y,test_size=0.2,random_state=42)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train = scaler.fit_transform (x_train)
x_test = scaler.transform(x_test)
x_train_df = pd.DataFrame(x_train,columns=x.columns)
x_test_df = pd.DataFrame(x_test,columns=x.columns)
print("Scaled Train Data:")
print(x_train_df.head())
print("\n Scaled Test Data:")
print(x_test_df.head())
# Out:
# Scaled Train Data:
#       hours
# 0  1.497392
# 1  1.149611
# 2 -1.632641
# 3 -0.241515
# 4 -0.589296
#
#  Scaled Test Data:
#       hours
# 0 -0.937078
# 1 -0.241515
# 2 -1.284859
# 3 -1.284859
# 4  0.454048
